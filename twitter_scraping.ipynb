# %% [markdown]
# <a href="https://colab.research.google.com/github/SandKrish/Classification_Prediction/blob/main/twitter_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /tmp/pip-install-0qdqugl6/twint_2452ea294600450ba39f11ef4c86c036
#   Running command git clone -q https://github.com/twintproject/twint.git /tmp/pip-install-0qdqugl6/twint_2452ea294600450ba39f11ef4c86c036
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...

# %%
pip install nest_asyncio

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint

c = twint.Config()

c.Search = ['covid']       # topic
c.Limit = 500      # number of Tweets to scrape
c.Store_csv = True       # store tweets in a csv file
c.Output = "covid.csv"     # path to csv file

twint.run.Search(c)
# Out:
# 1493298350980050953 2022-02-14 18:57:25 +0000 <MMichaelNY> What do I always say about Joe Biden and corrupt Labor Union donors?   "They had little need for them": Labor unions received millions in COVID-19 relief loans intended for businesses, @FreedomFdtn says. via @DailySignal  https://t.co/on5xi3ds2N
# 1493298350246010888 2022-02-14 18:57:25 +0000 <Josu50075334> @vovallediaz Y además enviaron a todos los niños pobres de colegios públicos para que se contagien con el covid y  se mueran los adultos mayores y demás en sus casas.
# 1493298348895449098 2022-02-14 18:57:25 +0000 <voxofreasonnow> @Iain_L Isn’t Health devolved to Scotland? Covid is health related?
# 1493298343832924162 2022-02-14 18:57:23 +0000 <Artistwhogives> @jessicaflres Why do people keep asking this question?????? I'm triple vaxxed and have not caught COVID. There are plenty other people who fit this description
# ...

# %%
import pandas as pd
df = pd.read_csv('covid.csv')

# %%
df.head()
# Out:
#                     id      conversation_id  ... trans_src trans_dest
# 0  1493298350980050953  1493298350980050953  ...       NaN        NaN
# 1  1493298350246010888  1493242160430395395  ...       NaN        NaN
# 2  1493298348895449098  1493107778235383808  ...       NaN        NaN
# 3  1493298343832924162  1493270709933649924  ...       NaN        NaN
# 4  1493298343648313345  1493298343648313345  ...       NaN        NaN
#
# [5 rows x 36 columns]

# %%
df['tweet']
# Out:
# 0      What do I always say about Joe Biden and corru...
# 1      @vovallediaz Y además enviaron a todos los niñ...
# 2      @Iain_L Isn’t Health devolved to Scotland? Cov...
# 3      @jessicaflres Why do people keep asking this q...
# 4      What if noga ke yona e tshwarisitšeng batho co...
#                              ...
# 495    Senior civil servant &amp; diplomat gets so st...
# 496    Last month, all 8 managers at my store had to ...
# 497    Covid: Camilla tests positive and PPE waste co...
# 498    @SaludSV reporta 4,002 fallecidos por Covid-19...
# 499    ONU denuncia 'alta exponencial' de violência p...
# Name: tweet, Length: 500, dtype: object

# %%
from google.colab import files
files.download('covid.csv')
